# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Pandas

# %%
df = pd.read_csv("Data_CSV.csv",sep = ";")
df.head()
# Out:
#       Province  Ho Chi Minh       Ha Noi   Hai Phong       Can Tho  \
# 0  Ho Chi Minh            0  1160,328125  1116,327582  124,3400088
# 1       Ha Noi  1160,328125            0  126,3858596  1235,554616
# 2   Hai Phong   1116,327582  126,3858596            0  1201,305114
# 3      Can Tho  124,3400088  1235,554616  1201,305114            0
# 4     Dong Nai  30,55865025  1144,991818  1098,305041  154,8364912
#
#       Dong Nai   Quang Nam      Bac Ninh    Hai Duong      Nghe An  ...  \
# 0  30,55865025  597,4550908  1160,851404  1132,378709  885,6947213  ...
# 1  1144,991818  656,6907774  59,49923806  88,53212523  274,8684043  ...
# 2  1098,305041  575,0459908  74,85572536  38,21237226  257,6134143  ...
# 3  154,8364912  706,3183301  1240,919573  1214,553251  961,0757824  ...
# 4            0  572,9234732  1144,164266  1115,131849  870,7558565  ...
#
#         Ha Nam     Hung Yen   Kien Giang     Lai Chau      Da Nang  \
# 0  1094,960639  1124,167884  253,2455707  1338,581425   612,139008
# 1  75,45833322  61,93742826  1253,715745   264,688208  632,8769261
# 2  81,04622641  67,79715301  1233,502621  388,3651168  552,1426803
# 3  1173,594679  1203,685561  141,4020524  1397,101956   719,138646
# 4  1078,756363  1107,678552  282,9012618  1327,577244  588,2014804
#
#       Dak Nong    Dien Bien    Vinh Phuc Latitude Longitude
# 0  197,3768841  1284,528508  1184,499927  10,7638  106,6436
# 1  1012,092866  258,9691499  25,15659633  21,1382   105,505
# 2  954,6846997  385,3549788  131,8554038     20,8  106,6667
# 3  318,3161613   1340,06003  1260,217144  10,0333  105,7833
# 4  169,2484011  1274,383073   1168,99858  10,9277  106,8681
#
# [5 rows x 66 columns]

# %%
df.columns
# Out:
# Index(['Province', 'Ho Chi Minh', 'Ha Noi', 'Hai Phong ', 'Can Tho',
#        'Dong Nai', 'Quang Nam ', 'Bac Ninh', 'Hai Duong', 'Nghe An', 'Hue',
#        'Thanh Hoa', 'Khanh Hoa ', 'Nam Dinh', 'Dak Lak', 'Thai Nguyen',
#        'Vung Tau', 'Ca Mau', 'Binh Dinh', 'Soc Trang', 'An Giang', 'Phu Tho',
#        'Thai Binh', 'Quang Ngai', 'Lam Dong', 'Binh Duong', 'Phu Yen',
#        'Bac Lieu', 'Dong Thap', 'Binh Thuan', 'Ninh Thuan', 'Quang Ninh',
#        'Ha Tinh', 'Quang Binh', 'Lang Son', 'Gia Lai', 'Long An', 'Tra Vinh',
#        'Ninh Binh', 'Tay Ninh', 'Tien Giang', 'Haa Binh', 'Kon Tum',
#        'Vinh Long', 'Hau Giang', 'Yen Bai', 'Quang Tri', 'Lao Cai', 'Ben Tre',
#        'Bac Giang', 'Cao Bang', 'Binh Phuoc', 'Ha Giang', 'Tuyen Quang',
#        'Bac Kan', 'Son La', 'Ha Nam', 'Hung Yen', 'Kien Giang', 'Lai Chau',
#        'Da Nang', 'Dak Nong', 'Dien Bien', 'Vinh Phuc', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
print(df.shape, df.ndim, sep = "\n")
# Out:
# (63, 66)
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 66 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Province     63 non-null     object
#  1   Ho Chi Minh  63 non-null     object
#  2   Ha Noi       63 non-null     object
#  3   Hai Phong    63 non-null     object
#  4   Can Tho      63 non-null     object
#  5   Dong Nai     63 non-null     object
#  6   Quang Nam    63 non-null     object
#  7   Bac Ninh     63 non-null     object
#  8   Hai Duong    63 non-null     object
#  9   Nghe An      63 non-null     object
#  10  Hue          63 non-null     object
#  11  Thanh Hoa    63 non-null     object
#  12  Khanh Hoa    63 non-null     object
#  13  Nam Dinh     63 non-null     object
#  14  Dak Lak      63 non-null     object
#  15  Thai Nguyen  63 non-null     object
#  16  Vung Tau     63 non-null     object
#  17  Ca Mau       63 non-null     object
#  18  Binh Dinh    63 non-null     object
#  19  Soc Trang    63 non-null     object
#  20  An Giang     63 non-null     object
#  21  Phu Tho      63 non-null     object
#  22  Thai Binh    63 non-null     object
#  23  Quang Ngai   63 non-null     object
#  24  Lam Dong     63 non-null     object
#  25  Binh Duong   63 non-null     object
#  26  Phu Yen      63 non-null     object
#  27  Bac Lieu     63 non-null     object
#  28  Dong Thap    63 non-null     object
#  29  Binh Thuan   63 non-null     object
#  30  Ninh Thuan   63 non-null     object
#  31  Quang Ninh   63 non-null     object
#  32  Ha Tinh      63 non-null     object
#  33  Quang Binh   63 non-null     object
#  34  Lang Son     63 non-null     object
#  35  Gia Lai      63 non-null     object
#  36  Long An      63 non-null     object
#  37  Tra Vinh     63 non-null     object
#  38  Ninh Binh    63 non-null     object
#  39  Tay Ninh     63 non-null     object
#  40  Tien Giang   63 non-null     object
#  41  Haa Binh     63 non-null     object
#  42  Kon Tum      63 non-null     object
#  43  Vinh Long    63 non-null     object
#  44  Hau Giang    63 non-null     object
#  45  Yen Bai      63 non-null     object
#  46  Quang Tri    63 non-null     object
#  47  Lao Cai      63 non-null     object
#  48  Ben Tre      63 non-null     object
#  49  Bac Giang    63 non-null     object
#  50  Cao Bang     63 non-null     object
#  51  Binh Phuoc   63 non-null     object
#  52  Ha Giang     63 non-null     object
#  53  Tuyen Quang  63 non-null     object
#  54  Bac Kan      63 non-null     object
#  55  Son La       63 non-null     object
#  56  Ha Nam       63 non-null     object
#  57  Hung Yen     63 non-null     object
#  58  Kien Giang   63 non-null     object
#  59  Lai Chau     63 non-null     object
#  60  Da Nang      63 non-null     object
#  61  Dak Nong     63 non-null     object
#  62  Dien Bien    63 non-null     object
#  63  Vinh Phuc    63 non-null     object
#  64  Latitude     63 non-null     object
#  65  Longitude    63 non-null     object
# dtypes: object(66)
# memory usage: 32.6+ KB

# %%
df.describe()
# Out:
#            Province Ho Chi Minh       Ha Noi   Hai Phong       Can Tho  \
# count            63          63           63           63           63
# unique           63          63           63           63           63
# top     Ho Chi Minh           0  1160,328125  1116,327582  124,3400088
# freq              1           1            1            1            1
#
#            Dong Nai   Quang Nam      Bac Ninh    Hai Duong      Nghe An  ...  \
# count            63           63           63           63           63  ...
# unique           63           63           63           63           63  ...
# top     30,55865025  597,4550908  1160,851404  1132,378709  885,6947213  ...
# freq              1            1            1            1            1  ...
#
#              Ha Nam     Hung Yen   Kien Giang     Lai Chau     Da Nang  \
# count            63           63           63           63          63
# unique           63           63           63           63          63
# top     1094,960639  1124,167884  253,2455707  1338,581425  612,139008
# freq              1            1            1            1           1
#
#            Dak Nong    Dien Bien    Vinh Phuc Latitude Longitude
# count            63           63           63       63        63
# unique           63           63           63       63        62
# top     197,3768841  1284,528508  1184,499927  10,7638     106,6
# freq              1            1            1        1         2
#
# [4 rows x 66 columns]

# %%
# now we can see this table has data_type obj > we can manipulating with this > we need convert object to float 
def obj_to_float(object):
    if object == "0":
        return int(object)
    else:
        list_obj = list(object)
        i = 0
        while i < len(object):
            if object[i] == ",":
                list_obj[i] = "."
                object = float("".join(list_obj))
                break
            i += 1 
        return object

for row in range(0,63):
    df.loc[row] = df.loc[row].apply(obj_to_float)

# %%
df.head()
# Out:
#       Province  Ho Chi Minh       Ha Noi   Hai Phong       Can Tho  \
# 0  Ho Chi Minh            0  1160.328125  1116.327582   124.340009
# 1       Ha Noi  1160.328125            0    126.38586  1235.554616
# 2   Hai Phong   1116.327582    126.38586            0  1201.305114
# 3      Can Tho   124.340009  1235.554616  1201.305114            0
# 4     Dong Nai     30.55865  1144.991818  1098.305041   154.836491
#
#       Dong Nai  Quang Nam      Bac Ninh    Hai Duong     Nghe An  ...  \
# 0     30.55865  597.455091  1160.851404  1132.378709  885.694721  ...
# 1  1144.991818  656.690777    59.499238    88.532125  274.868404  ...
# 2  1098.305041  575.045991    74.855725    38.212372  257.613414  ...
# 3   154.836491   706.31833  1240.919573  1214.553251  961.075782  ...
# 4            0  572.923473  1144.164266  1115.131849  870.755857  ...
#
#         Ha Nam     Hung Yen   Kien Giang     Lai Chau     Da Nang  \
# 0  1094.960639  1124.167884   253.245571  1338.581425  612.139008
# 1    75.458333    61.937428  1253.715745   264.688208  632.876926
# 2    81.046226    67.797153  1233.502621   388.365117   552.14268
# 3  1173.594679  1203.685561   141.402052  1397.101956  719.138646
# 4  1078.756363  1107.678552   282.901262  1327.577244   588.20148
#
#       Dak Nong    Dien Bien    Vinh Phuc Latitude Longitude
# 0   197.376884  1284.528508  1184.499927  10.7638  106.6436
# 1  1012.092866    258.96915    25.156596  21.1382   105.505
# 2     954.6847   385.354979   131.855404     20.8  106.6667
# 3   318.316161   1340.06003  1260.217144  10.0333  105.7833
# 4   169.248401  1274.383073   1168.99858  10.9277  106.8681
#
# [5 rows x 66 columns]

# %%
print(df["Latitude"].max(),df["Latitude"].min())
# Out:
# 22.8233 9.1833

# %%
print(df["Longitude"].max(),df["Longitude"].min())
# Out:
# 109.3086 103.107651

# %% [markdown]
# # Matplotlib

# %%
Longitude, Latitude, Province = df["Longitude"],df["Latitude"],df["Province"]

# %%
# change style plt
plt.style.available
plt.style.use('seaborn-whitegrid')

# size fig
plt.figure(figsize = (15,15))

# scatter
# plt.scatter(Longitude,Latitude, c = color, alpha = 0.4)

for x, y in zip(Longitude, Latitude):
    rgb = np.random.rand(3,)
    plt.scatter(x, y, c=[rgb], alpha = 0.5)

plt.axis([100,112,8,30])
plt.axis("tight")

# label
plt.title("Map of Vietnam", color = "red",fontsize = 20, alpha = 0.5)
plt.xlabel("Longitude", fontsize = 10)
plt.ylabel("Latitude", fontsize = 10)

for i in range(len(Province)):
    plt.text(Longitude[i],Latitude[i],Province[i],color = "black", fontsize = 6,alpha = 0.7)
# show
plt.show();

# %% [markdown]
# # NumPy

# %%
df.head()
# Out:
#       Province  Ho Chi Minh       Ha Noi   Hai Phong       Can Tho  \
# 0  Ho Chi Minh            0  1160.328125  1116.327582   124.340009
# 1       Ha Noi  1160.328125            0    126.38586  1235.554616
# 2   Hai Phong   1116.327582    126.38586            0  1201.305114
# 3      Can Tho   124.340009  1235.554616  1201.305114            0
# 4     Dong Nai     30.55865  1144.991818  1098.305041   154.836491
#
#       Dong Nai  Quang Nam      Bac Ninh    Hai Duong     Nghe An  ...  \
# 0     30.55865  597.455091  1160.851404  1132.378709  885.694721  ...
# 1  1144.991818  656.690777    59.499238    88.532125  274.868404  ...
# 2  1098.305041  575.045991    74.855725    38.212372  257.613414  ...
# 3   154.836491   706.31833  1240.919573  1214.553251  961.075782  ...
# 4            0  572.923473  1144.164266  1115.131849  870.755857  ...
#
#         Ha Nam     Hung Yen   Kien Giang     Lai Chau     Da Nang  \
# 0  1094.960639  1124.167884   253.245571  1338.581425  612.139008
# 1    75.458333    61.937428  1253.715745   264.688208  632.876926
# 2    81.046226    67.797153  1233.502621   388.365117   552.14268
# 3  1173.594679  1203.685561   141.402052  1397.101956  719.138646
# 4  1078.756363  1107.678552   282.901262  1327.577244   588.20148
#
#       Dak Nong    Dien Bien    Vinh Phuc Latitude Longitude
# 0   197.376884  1284.528508  1184.499927  10.7638  106.6436
# 1  1012.092866    258.96915    25.156596  21.1382   105.505
# 2     954.6847   385.354979   131.855404     20.8  106.6667
# 3   318.316161   1340.06003  1260.217144  10.0333  105.7833
# 4   169.248401  1274.383073   1168.99858  10.9277  106.8681
#
# [5 rows x 66 columns]

# %%
arr = df.values
arr
# Out:
# array([['Ho Chi Minh', 0, 1160.328125, ..., 1184.499927, 10.7638,
#         106.6436],
#        ['Ha Noi', 1160.328125, 0, ..., 25.15659633, 21.1382, 105.505],
#        ['Hai Phong ', 1116.327582, 126.3858596, ..., 131.8554038, 20.8,
#         106.6667],
#        ...,
#        ['Dak Nong', 197.3768841, 1012.092866, ..., 1035.265315,
#         12.264648, 107.609802],
#        ['Dien Bien', 1284.528508, 258.9691499, ..., 257.1204584,
#         21.804232, 103.107651],
#        ['Vinh Phuc', 1184.499927, 25.15659633, ..., 0, 21.360882,
#         105.54744]], dtype=object)

# %%
arr_distance = arr[:,1:-2]
arr_distance
# Out:
# array([[0, 1160.328125, 1116.327582, ..., 197.3768841, 1284.528508,
#         1184.499927],
#        [1160.328125, 0, 126.3858596, ..., 1012.092866, 258.9691499,
#         25.15659633],
#        [1116.327582, 126.3858596, 0, ..., 954.6846997, 385.3549788,
#         131.8554038],
#        ...,
#        [197.3768841, 1012.092866, 954.6846997, ..., 0, 1163.816103,
#         1035.265315],
#        [1284.528508, 258.9691499, 385.3549788, ..., 1163.816103, 0,
#         257.1204584],
#        [1184.499927, 25.15659633, 131.8554038, ..., 1035.265315,
#         257.1204584, 0]], dtype=object)
